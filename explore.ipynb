# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from itertools import combinations

from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, QuantileTransformer
from sklearn.model_selection import train_test_split

import copy

import wrangle

from scipy import stats

seed = 55

# %% [markdown]
# ## 2. Make sure to perform a train, validate, test split before and use only your train dataset to explore the relationships between independent variables with other independent variables or independent variables with your target variable.

# %%
zillow = wrangle.get_zillow()
zillow = wrangle.drop_zill(zillow)
train, val, test = wrangle.train_val_test(zillow)
train.shape, val.shape, test.shape
# Out:
# ((1498164, 7), (321035, 7), (321036, 7))

# %%
train.head(2)
# Out:
#         bed  bath    sqft     value    year      tax    fips
# 274677  3.0   2.0  2159.0  364577.0  1967.0  4517.62  6037.0
# 283102  2.0   1.0  1072.0  162390.0  1954.0  1996.96  6037.0

# %% [markdown]
# ## 3. Write a function named plot_variable_pairs that accepts a dataframe as input and plots all of the pairwise relationships along with the regression line for each pair.

# %%
def plot_variable_pairs(df):
    sns.pairplot(df, kind='reg', plot_kws={'line_kws':{'color': 'red'}})

# %%
plot_variable_pairs(train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 plot_variable_pairs(train)
#
# Cell In[9], line 2, in plot_variable_pairs(df)
#       1 def plot_variable_pairs(df):
# ----> 2     sns.pairplot(df, kind='reg', plot_kws={'line_kws':{'color': 'red'}})
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/seaborn/axisgrid.py:2161, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2159 elif kind == "reg":
#    2160     from .regression import regplot  # Avoid circular import
# -> 2161     plotter(regplot, **plot_kws)
#    2162 elif kind == "kde":
#    2163     from .distributions import kdeplot  # Avoid circular import
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/seaborn/axisgrid.py:1419, in PairGrid.map_offdiag(self, func, **kwargs)
#    1408 """Plot with a bivariate function on the off-diagonal subplots.
#    1409
#    1410 Parameters
#    (...)
#    1416
#    1417 """
#    1418 if self.square_grid:
# -> 1419     self.map_lower(func, **kwargs)
#    1420     if not self._corner:
#    1421         self.map_upper(func, **kwargs)
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/seaborn/axisgrid.py:1389, in PairGrid.map_lower(self, func, **kwargs)
#    1378 """Plot with a bivariate function on the lower diagonal subplots.
#    1379
#    1380 Parameters
#    (...)
#    1386
#    1387 """
#    1388 indices = zip(*np.tril_indices_from(self.axes, -1))
# -> 1389 self._map_bivariate(func, indices, **kwargs)
#    1390 return self
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/seaborn/axisgrid.py:1568, in PairGrid._map_bivariate(self, func, indices, **kwargs)
#    1566     if ax is None:  # i.e. we are in corner mode
#    1567         continue
# -> 1568     self._plot_bivariate(x_var, y_var, ax, func, **kws)
#    1569 self._add_axis_labels()
#    1571 if "hue" in signature(func).parameters:
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/seaborn/axisgrid.py:1577, in PairGrid._plot_bivariate(self, x_var, y_var, ax, func, **kwargs)
#    1575 """Draw a bivariate plot on the specified axes."""
#    1576 if "hue" not in signature(func).parameters:
# -> 1577     self._plot_bivariate_iter_hue(x_var, y_var, ax, func, **kwargs)
#    1578     return
#    1580 kwargs = kwargs.copy()
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/seaborn/axisgrid.py:1651, in PairGrid._plot_bivariate_iter_hue(self, x_var, y_var, ax, func, **kwargs)
#    1648     kws["label"] = label_k
#    1650 if str(func.__module__).startswith("seaborn"):
# -> 1651     func(x=x, y=y, **kws)
#    1652 else:
#    1653     func(x, y, **kws)
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/seaborn/regression.py:759, in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     757 scatter_kws["marker"] = marker
#     758 line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 759 plotter.plot(ax, scatter_kws, line_kws)
#     760 return ax
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/seaborn/regression.py:368, in _RegressionPlotter.plot(self, ax, scatter_kws, line_kws)
#     365     self.scatterplot(ax, scatter_kws)
#     367 if self.fit_reg:
# --> 368     self.lineplot(ax, line_kws)
#     370 # Label the axes
#     371 if hasattr(self.x, "name"):
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/seaborn/regression.py:413, in _RegressionPlotter.lineplot(self, ax, kws)
#     411 """Draw the model."""
#     412 # Fit the regression model
# --> 413 grid, yhat, err_bands = self.fit_regression(ax)
#     414 edges = grid[0], grid[-1]
#     416 # Get set default aesthetics
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/seaborn/regression.py:219, in _RegressionPlotter.fit_regression(self, ax, x_range, grid)
#     217     yhat, yhat_boots = self.fit_logx(grid)
#     218 else:
# --> 219     yhat, yhat_boots = self.fit_fast(grid)
#     221 # Compute the confidence interval at each grid point
#     222 if ci is None:
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/seaborn/regression.py:240, in _RegressionPlotter.fit_fast(self, grid)
#     237 if self.ci is None:
#     238     return yhat, None
# --> 240 beta_boots = algo.bootstrap(X, y,
#     241                             func=reg_func,
#     242                             n_boot=self.n_boot,
#     243                             units=self.units,
#     244                             seed=self.seed).T
#     245 yhat_boots = grid.dot(beta_boots).T
#     246 return yhat, yhat_boots
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/seaborn/algorithms.py:98, in bootstrap(*args, **kwargs)
#      96     resampler = integers(0, n, n, dtype=np.intp)  # intp is indexing dtype
#      97     sample = [a.take(resampler, axis=0) for a in args]
# ---> 98     boot_dist.append(f(*sample, **func_kwargs))
#      99 return np.array(boot_dist)
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/seaborn/regression.py:232, in _RegressionPlotter.fit_fast.<locals>.reg_func(_x, _y)
#     231 def reg_func(_x, _y):
# --> 232     return np.linalg.pinv(_x).dot(_y)
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/numpy/linalg/linalg.py:2022, in pinv(a, rcond, hermitian)
#    2020     return wrap(res)
#    2021 a = a.conjugate()
# -> 2022 u, s, vt = svd(a, full_matrices=False, hermitian=hermitian)
#    2024 # discard small singular values
#    2025 cutoff = rcond[..., newaxis] * amax(s, axis=-1, keepdims=True)
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/numpy/linalg/linalg.py:1681, in svd(a, full_matrices, compute_uv, hermitian)
#    1678         gufunc = _umath_linalg.svd_n_s
#    1680 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1681 u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1682 u = u.astype(result_t, copy=False)
#    1683 s = s.astype(_realType(result_t), copy=False)
#
# KeyboardInterrupt:

# %%
def plot_variable_pairs(df):
    # Select only the continuous variables from the DataFrame
    continuous_vars = df.select_dtypes(include=['float64', 'int64'])
    # Create a pair plot with regression lines
    sns.set(style="ticks")
    sns.pairplot(continuous_vars.sample(10_000), kind="reg", plot_kws={'line_kws':{'color':'red'}})
    # Display the plot
    plt.show()

# %%
def plot_variable_pairs(df):
    pairs = list(combinations(df.columns,2))
    for col1, col2 in pairs:
        sns.lmplot(x="col", y="final_grade", data=train, line_kws={'color': 'red'})
    
    sns.lmplot(x="exam1", y="final_grade", data=train, line_kws={'color': 'red'})
    plt.show()
